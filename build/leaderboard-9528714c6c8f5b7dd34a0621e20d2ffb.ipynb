# %% [markdown]
# # Leader board
#
# Check out the latest challenge results here!
#
# :::{tip}
#
# Be sure to refresh the page to get the latest results.
# :::
#
# ## Top 10 teams
#
# Check out the evolution of the leading teams's progress!

# %%
# Rules of the game
MAX_GATES = 150
MAX_PARAMS = 60

# Leaderboard config
NUM_LEADERS = 10

# Helper function to compute total submission score
def compute_score(entry):
    # Accuracy 
    score = entry.Accuracy

    # Gate penalty
    score += (MAX_GATES - entry.Gates) / MAX_GATES

    # Params penalty
    score += (MAX_PARAMS - entry.Parameters) / MAX_PARAMS
    return score

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Retrieve submissions and compute total score
results = pd.read_csv("results.csv", index_col=False)
results["Timestamp"] = pd.to_datetime(results.Timestamp, unit="s")
results.insert(1, "Score", results.apply(compute_score, axis=1))

# Get top teams, sorted by their highest scoring submission
gpby = results.groupby("Team")
top_teams = results.iloc[gpby.idxmax().Score].sort_values("Score", ascending=False)
leaders = top_teams[:NUM_LEADERS].reset_index(drop=True)

# Extract leading teams' data
agg = gpby.agg(list)
plt.xticks(rotation=70)
[plt.plot(agg.loc[team].Timestamp, agg.loc[team].Score) for team in leaders.Team]

# Make the plot pretty
plt.xlabel("Submission time")
plt.ylabel("Total score")
plt.legend(leaders.Team, bbox_to_anchor=(1.04, 1), loc="upper left");
# Out:
# /opt/hostedtoolcache/Python/3.11.9/x64/lib/python3.11/site-packages/IPython/core/events.py:82: UserWarning: Glyph 49548 (\N{HANGUL SYLLABLE SO}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# /opt/hostedtoolcache/Python/3.11.9/x64/lib/python3.11/site-packages/IPython/core/events.py:82: UserWarning: Glyph 45208 (\N{HANGUL SYLLABLE NA}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# /opt/hostedtoolcache/Python/3.11.9/x64/lib/python3.11/site-packages/IPython/core/events.py:82: UserWarning: Glyph 47924 (\N{HANGUL SYLLABLE MU}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# /opt/hostedtoolcache/Python/3.11.9/x64/lib/python3.11/site-packages/IPython/core/events.py:82: UserWarning: Glyph 44032 (\N{HANGUL SYLLABLE GA}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# /opt/hostedtoolcache/Python/3.11.9/x64/lib/python3.11/site-packages/IPython/core/events.py:82: UserWarning: Glyph 49296 (\N{HANGUL SYLLABLE BBI}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# /opt/hostedtoolcache/Python/3.11.9/x64/lib/python3.11/site-packages/IPython/core/events.py:82: UserWarning: Glyph 51648 (\N{HANGUL SYLLABLE JI}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# /opt/hostedtoolcache/Python/3.11.9/x64/lib/python3.11/site-packages/IPython/core/events.py:82: UserWarning: Glyph 47732 (\N{HANGUL SYLLABLE MYEON}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# /opt/hostedtoolcache/Python/3.11.9/x64/lib/python3.11/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 49548 (\N{HANGUL SYLLABLE SO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/hostedtoolcache/Python/3.11.9/x64/lib/python3.11/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 45208 (\N{HANGUL SYLLABLE NA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/hostedtoolcache/Python/3.11.9/x64/lib/python3.11/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 47924 (\N{HANGUL SYLLABLE MU}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/hostedtoolcache/Python/3.11.9/x64/lib/python3.11/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 44032 (\N{HANGUL SYLLABLE GA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/hostedtoolcache/Python/3.11.9/x64/lib/python3.11/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 49296 (\N{HANGUL SYLLABLE BBI}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/hostedtoolcache/Python/3.11.9/x64/lib/python3.11/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 51648 (\N{HANGUL SYLLABLE JI}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/hostedtoolcache/Python/3.11.9/x64/lib/python3.11/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 47732 (\N{HANGUL SYLLABLE MYEON}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
leaders.rename(columns={"Score": "Top Score"})
# Out:
#                   Team  Top Score  Commit           Timestamp  Accuracy  \
# 0  Quantum Visionaries  55.616667  00ce1d 2024-06-21 03:45:55      54.0
# 1   Expert Classifiers  54.656667  9b7ce8 2024-06-21 05:30:36      53.0
# 2             Highfive  54.616667  4d4004 2024-06-21 08:25:16      53.0
# 3             소나무가 삐지면  54.616667  9f0161 2024-06-21 04:40:52      53.0
#
#    Gates  Parameters
# 0     10          19
# 1     14          15
# 2     10          19
# 3     10          19

# %% [markdown]
# ## Submission history
#
# Please find all the challenge submissions below. Most recent submissions are at the top!

# %%
results.sort_values("Timestamp", ascending=False).reset_index(drop=True)
# Out:
#                    Team      Score  Commit           Timestamp  Accuracy  \
# 0              소나무가 삐지면  51.616667  a2cd91 2024-06-21 13:44:43      50.0
# 1              Highfive  54.616667  c88ecf 2024-06-21 13:16:07      53.0
# 2              Highfive  50.796667  3a22d6 2024-06-21 10:41:42      49.0
# 3              Highfive  52.796667  6e8b3e 2024-06-21 10:40:56      51.0
# 4              Highfive  50.796667  6c0b1f 2024-06-21 10:03:39      49.0
# 5              Highfive  51.820000  6e7b91 2024-06-21 09:24:15      50.0
# 6              Highfive  54.616667  4d4004 2024-06-21 08:25:16      53.0
# 7              Highfive  48.773333  d7d214 2024-06-21 08:24:01      47.0
# 8    Expert Classifiers  54.656667  9b7ce8 2024-06-21 05:30:36      53.0
# 9    Expert Classifiers  54.616667  17ad4a 2024-06-21 05:30:33      53.0
# 10             소나무가 삐지면  54.616667  9f0161 2024-06-21 04:40:52      53.0
# 11   Expert Classifiers  54.616667  276298 2024-06-21 04:21:24      53.0
# 12  Quantum Visionaries  55.616667  00ce1d 2024-06-21 03:45:55      54.0
#
#     Gates  Parameters
# 0      10          19
# 1      10          19
# 2       8           9
# 3       8           9
# 4       8           9
# 5       7           8
# 6      10          19
# 7       9          10
# 8      14          15
# 9      10          19
# 10     10          19
# 11     10          19
# 12     10          19
