# %% [markdown]
# # Leader board
#
# Check out the latest challenge results here!
#
# :::{tip}
#
# Be sure to refresh the page to get the latest results.
# :::
#
# ## Top 10 teams
#
# Check out the evolution of the leading teams's progress!

# %%
# Rules of the game
MAX_GATES = 150
MAX_PARAMS = 60

# Leaderboard config
NUM_LEADERS = 10

# Helper function to compute total submission score
def compute_score(entry):
    # Accuracy 
    score = entry.Accuracy

    # Gate penalty
    score += 5 * (MAX_GATES - entry.Gates) / MAX_GATES

    # Params penalty
    score += 5 * (MAX_PARAMS - entry.Parameters) / MAX_PARAMS
    return score

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Retrieve submissions and compute total score
results = pd.read_csv("results.csv", index_col=False)
results["Timestamp"] = pd.to_datetime(results.Timestamp, unit="s")
results.insert(1, "Score", results.apply(compute_score, axis=1))

# Get top teams, sorted by their highest scoring submission
gpby = results.groupby("Team")
top_teams = results.iloc[gpby.idxmax().Score].sort_values("Score", ascending=False)
leaders = top_teams[:NUM_LEADERS].reset_index(drop=True)

# Extract leading teams' data
agg = gpby.agg(list)
plt.xticks(rotation=70)
[plt.plot(agg.loc[team].Timestamp, agg.loc[team].Score) for team in leaders.Team]

# Make the plot pretty
plt.xlabel("Submission time")
plt.ylabel("Total score")
plt.legend(leaders.Team, bbox_to_anchor=(1.04, 1), loc="upper left");
# Out:
# /opt/hostedtoolcache/Python/3.11.9/x64/lib/python3.11/site-packages/IPython/core/events.py:82: UserWarning: Glyph 49548 (\N{HANGUL SYLLABLE SO}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# /opt/hostedtoolcache/Python/3.11.9/x64/lib/python3.11/site-packages/IPython/core/events.py:82: UserWarning: Glyph 45208 (\N{HANGUL SYLLABLE NA}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# /opt/hostedtoolcache/Python/3.11.9/x64/lib/python3.11/site-packages/IPython/core/events.py:82: UserWarning: Glyph 47924 (\N{HANGUL SYLLABLE MU}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# /opt/hostedtoolcache/Python/3.11.9/x64/lib/python3.11/site-packages/IPython/core/events.py:82: UserWarning: Glyph 44032 (\N{HANGUL SYLLABLE GA}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# /opt/hostedtoolcache/Python/3.11.9/x64/lib/python3.11/site-packages/IPython/core/events.py:82: UserWarning: Glyph 49296 (\N{HANGUL SYLLABLE BBI}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# /opt/hostedtoolcache/Python/3.11.9/x64/lib/python3.11/site-packages/IPython/core/events.py:82: UserWarning: Glyph 51648 (\N{HANGUL SYLLABLE JI}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# /opt/hostedtoolcache/Python/3.11.9/x64/lib/python3.11/site-packages/IPython/core/events.py:82: UserWarning: Glyph 47732 (\N{HANGUL SYLLABLE MYEON}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# /opt/hostedtoolcache/Python/3.11.9/x64/lib/python3.11/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 49548 (\N{HANGUL SYLLABLE SO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/hostedtoolcache/Python/3.11.9/x64/lib/python3.11/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 45208 (\N{HANGUL SYLLABLE NA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/hostedtoolcache/Python/3.11.9/x64/lib/python3.11/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 47924 (\N{HANGUL SYLLABLE MU}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/hostedtoolcache/Python/3.11.9/x64/lib/python3.11/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 44032 (\N{HANGUL SYLLABLE GA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/hostedtoolcache/Python/3.11.9/x64/lib/python3.11/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 49296 (\N{HANGUL SYLLABLE BBI}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/hostedtoolcache/Python/3.11.9/x64/lib/python3.11/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 51648 (\N{HANGUL SYLLABLE JI}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/hostedtoolcache/Python/3.11.9/x64/lib/python3.11/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 47732 (\N{HANGUL SYLLABLE MYEON}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
leaders.rename(columns={"Score": "Top Score"})
# Out:
#                   Team  Top Score  Commit           Timestamp  Accuracy  \
# 0             Highfive  65.133333  b4e98d 2024-06-22 05:52:43      56.0
# 1          Pine Tree 2  62.100000  62a97c 2024-06-22 08:27:02      53.0
# 2  Quantum Visionaries  62.083333  00ce1d 2024-06-21 03:45:55      54.0
# 3            Pine Tree  62.066667  31ecdc 2024-06-22 05:15:24      53.0
# 4   Expert Classifiers  61.283333  9b7ce8 2024-06-21 05:30:36      53.0
# 5             소나무가 삐지면  61.083333  9f0161 2024-06-21 04:40:52      53.0
#
#    Gates  Parameters
# 0      6           8
# 1      7           8
# 2     10          19
# 3      8           8
# 4     14          15
# 5     10          19

# %% [markdown]
# ## Submission history
#
# Please find all the challenge submissions below. Most recent submissions are at the top!

# %%
results.sort_values("Timestamp", ascending=False).reset_index(drop=True)
# Out:
#                    Team      Score  Commit           Timestamp  Accuracy  \
# 0              소나무가 삐지면  52.966667  2f7a0b 2024-06-22 08:40:48      45.0
# 1           Pine Tree 2  56.450000  f0066d 2024-06-22 08:28:11      49.0
# 2           Pine Tree 2  62.100000  62a97c 2024-06-22 08:27:02      53.0
# 3           Pine Tree 2  60.083333  722632 2024-06-22 08:23:14      52.0
# 4              Highfive  60.866667  961603 2024-06-22 08:21:59      52.0
# 5             Pine Tree  55.233333  9e0186 2024-06-22 08:19:42      46.0
# 6             Pine Tree  55.233333  9cf8b7 2024-06-22 08:18:29      46.0
# 7             Pine Tree  55.233333  d85742 2024-06-22 08:01:22      46.0
# 8           Pine Tree 2  61.083333  0ff8d4 2024-06-22 07:12:31      53.0
# 9             Pine Tree  59.233333  94b99d 2024-06-22 07:00:59      50.0
# 10            Pine Tree  62.066667  eeaec7 2024-06-22 06:59:59      53.0
# 11            Pine Tree  62.066667  4ede22 2024-06-22 06:59:50      53.0
# 12            Pine Tree  61.083333  e4e231 2024-06-22 06:47:27      53.0
# 13            Pine Tree  60.350000  6a7576 2024-06-22 06:45:30      53.0
# 14            Pine Tree  58.083333  08df68 2024-06-22 06:43:54      50.0
# 15          Pine Tree 2  61.083333  2110dc 2024-06-22 06:34:44      53.0
# 16          Pine Tree 2  58.083333  d46c60 2024-06-22 06:31:02      50.0
# 17            Pine Tree  57.066667  bf6969 2024-06-22 06:00:58      48.0
# 18             Highfive  65.133333  b4e98d 2024-06-22 05:52:43      56.0
# 19            Pine Tree  62.066667  31ecdc 2024-06-22 05:15:24      53.0
# 20            Pine Tree  61.983333  77c6f5 2024-06-22 04:49:12      53.0
# 21            Pine Tree  57.450000  e5ac08 2024-06-22 04:36:15      49.0
# 22            Pine Tree  58.100000  a29225 2024-06-22 04:34:20      49.0
# 23             Highfive  63.133333  f5b6df 2024-06-22 04:19:19      54.0
# 24             Highfive  62.133333  0eb4cc 2024-06-22 04:17:37      53.0
# 25             소나무가 삐지면  59.100000  9647ce 2024-06-22 04:08:49      50.0
# 26             Highfive  59.083333  691e74 2024-06-22 02:29:22      50.0
# 27             Highfive  59.083333  1f7431 2024-06-22 02:28:38      50.0
# 28             소나무가 삐지면  60.450000  d1b18b 2024-06-22 02:24:58      52.0
# 29   Expert Classifiers  51.700000  480933 2024-06-21 17:12:36      44.0
# 30             Highfive  61.083333  1c7c89 2024-06-21 16:40:07      53.0
# 31             Highfive  61.083333  a901bf 2024-06-21 16:35:04      53.0
# 32             Highfive  62.083333  14e9ad 2024-06-21 15:41:23      54.0
# 33             Highfive  51.750000  561337 2024-06-21 15:41:01      46.0
# 34             소나무가 삐지면  57.750000  ab98e9 2024-06-21 15:21:56      50.0
# 35   Expert Classifiers  48.700000  b3ccab 2024-06-21 13:48:08      41.0
# 36             소나무가 삐지면  57.083333  4bbda2 2024-06-21 13:44:48      49.0
# 37             소나무가 삐지면  58.083333  a2cd91 2024-06-21 13:44:43      50.0
# 38             Highfive  61.083333  c88ecf 2024-06-21 13:16:07      53.0
# 39             Highfive  57.983333  3a22d6 2024-06-21 10:41:42      49.0
# 40             Highfive  59.983333  6e8b3e 2024-06-21 10:40:56      51.0
# 41             Highfive  57.983333  6c0b1f 2024-06-21 10:03:39      49.0
# 42             Highfive  59.100000  6e7b91 2024-06-21 09:24:15      50.0
# 43             Highfive  61.083333  4d4004 2024-06-21 08:25:16      53.0
# 44             Highfive  55.866667  d7d214 2024-06-21 08:24:01      47.0
# 45   Expert Classifiers  61.283333  9b7ce8 2024-06-21 05:30:36      53.0
# 46   Expert Classifiers  61.083333  17ad4a 2024-06-21 05:30:33      53.0
# 47             소나무가 삐지면  61.083333  9f0161 2024-06-21 04:40:52      53.0
# 48   Expert Classifiers  61.083333  276298 2024-06-21 04:21:24      53.0
# 49  Quantum Visionaries  62.083333  00ce1d 2024-06-21 03:45:55      54.0
#
#     Gates  Parameters
# 0      11          20
# 1      14          25
# 2       7           8
# 3      10          19
# 4       9          10
# 5       3           8
# 6       3           8
# 7       3           8
# 8      10          19
# 9       3           8
# 10      8           8
# 11      8           8
# 12     10          19
# 13     12          27
# 14     10          19
# 15     10          19
# 16     10          19
# 17      8           8
# 18      6           8
# 19      8           8
# 20      8           9
# 21      9          15
# 22      7           8
# 23      6           8
# 24      6           8
# 25      7           8
# 26      5           9
# 27      5           9
# 28      9          15
# 29     19          20
# 30     10          19
# 31     10          19
# 32     10          19
# 33     10          47
# 34     10          23
# 35     19          20
# 36     10          19
# 37     10          19
# 38     10          19
# 39      8           9
# 40      8           9
# 41      8           9
# 42      7           8
# 43     10          19
# 44      9          10
# 45     14          15
# 46     10          19
# 47     10          19
# 48     10          19
# 49     10          19
